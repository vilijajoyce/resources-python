# %% [markdown]
# <a href="https://colab.research.google.com/github/vilijajoyce/python-resources/blob/main/python_lake_007_visual_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualizing Data
# Perceive patterns in data and communicate them.
#
# ## What is a visualization?
# John Snow's 1854 map of cholera deaths. Background is a street map. On top = large collection of orange dots each representing a cholera death. Other sybmols (in purple) represent water pumps. Clustered around 1 particular pump (handle removed and ended cholera outbreak).
#
# ## Why create visualizations?
# Easier to detect patterns.

# %%
# Import seaborn - a Python data visualization library based on matplotlib
import seaborn as sns
sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each of 4 datasets
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# Note that mean, correlation, regression lines are all similar
# BUT, datasets are very different from each other
# dset 1 - linear
# dset 2 - non-linear (parabolic)
# dset 3/4 - influenced by outliers
# Descriptive stats may not have picked up on these differences - but plots do

# %% [markdown]
# ## Exploratory data analysis
# Summarize main patterns or findings.
# No clear hypothesis.
# Sensemaking.
#
# ## Communication
# Use figures to communicate the known and understood results of a dataset. Figure in a publication/presentation.
#
# ## Sensemaking
# Generating meaningful explanations or understandings for possibly incomplete or noise data patterns in the environment. We never know exactly where the patterns might lie (e.g. linear relationship or nonlinear or other). Use several plots.
#
# ## Style and substance
# Tufte 2001, Healy 2019.
# Careful of plots that try to purposely mislead you and sway your opinion (e.g. gun deaths from Florida Dept of Law Enforcement). Always check the axes.
#
# Careful of Excel default plots (3-D often not needed).
#
# Seaborn provides visually pleasing plots.
#
# ## How to make plots in Python
# Mostly focus on matplotlib library. Matplotlib=general purpose graphics and plotting library for Python. Closely linked to pandas and seaborn.

# %%
# Intro to matplotlib
# Make a small list of numbers and then plot 
# Import matplotlib pyplot module
import matplotlib.pyplot as plt

# Create short list of fibonacci numbers
fibonacci = [1,1,2,3,5,8,13]

# Call plt.plot to create a basic plot - plot assumes numbers are y values
plt.plot(fibonacci)

# Add y and x-axis labels
plt.ylabel('some fibonacci numbers')
plt.xlabel("index")

# Display the plot
plt.show()

# %%
# Plot a second line, change colors, change type of line, add legend
import matplotlib.pyplot as plt
fibonacci = [1,1,2,3,5,8,13]
plt.plot(fibonacci,'b:', label='fibonacci') # Set to blue dotted line and add label for legend
linear = [1,2,3,4,5,6,7]
plt.plot(linear,'g-', label='count') # Set to green solid line and add label for legend
plt.ylabel('some numbers')
plt.xlabel("index")
plt.legend(loc='upper left') # Plot legend
plt.show()

# %% [markdown]
# ## Links to matplotlib resources
# [Intro to pyplot](https://matplotlib.org/stable/tutorials/introductory/pyplot.html): this is a very basic introductory mode of using matplotlib most similar to matlab
#
# [Colors in matplotlib](https://matplotlib.org/stable/tutorials/colors/colors.html): learn about all the color options
#
# [A guide to legends](https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html): how to customize legends
#
# [A gallery of examples with code](https://matplotlib.org/3.4.3/tutorials/introductory/sample_plots.html): Check here and perhaps you can get some starter code

# %% [markdown]
# ## Technical stuff

# %%
fig = plt.figure()  # an empty figure with no axes

# %%
fig, ax_lst = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
fig, ax_lst = plt.subplots(5, 3)  # a figure with a 5x3 grid of Axes

# %%
fig, ax_lst = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes - add title to each panel
ax_lst[0,0].set_title("Panel 1")
ax_lst[0,1].set_title("Panel 2")
ax_lst[1,0].set_title("Panel 3")
ax_lst[1,1].set_title("Panel 4")
# Out:
# Text(0.5, 1.0, 'Panel 4')

# %%
fig, ax_lst = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes - add x-labels and fix spacing
ax_lst[0,0].set_title("Panel 1")
ax_lst[0,0].set_xlabel("x")
ax_lst[0,1].set_title("Panel 2")
ax_lst[0,1].set_xlabel("x")
ax_lst[1,0].set_title("Panel 3")
ax_lst[1,0].set_xlabel("x")
ax_lst[1,1].set_title("Panel 4")
ax_lst[1,1].set_xlabel("x")
plt.tight_layout()

# %%
fig, ax_lst = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
fig.suptitle('Vertically stacked subplots')  # add a overall title, add x and y labels to outermost parts only
ax_lst[0,0].set_title("Panel 1")
ax_lst[0,1].set_title("Panel 2")
ax_lst[1,0].set_title("Panel 3")
ax_lst[1,1].set_title("Panel 4")
# add
for ax in ax_lst.flat:
    ax.set(xlabel='x-label', ylabel='y-label')
    ax.label_outer()
plt.tight_layout()

# %%
import numpy as np
# Create oscillatory patterns
x1 = np.linspace(0.0, 5.0, 50)  # first use linspace to create the xvalues
x2 = np.linspace(0.0, 2.0, 50) 
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1) # next use the cosine function to create a dampened
y2 = np.cos(2 * np.pi * x2) # and un-dampened oscillatory function

# Create two subplots sharing y axis
fig, (ax1, ax2) = plt.subplots(2, sharey=True)

ax1.plot(x1, y1, 'ko-')
ax1.set(title='A tale of 2 subplots', ylabel='Damped oscillation')

ax2.plot(x2, y2, 'r.-')
ax2.set(xlabel='time (s)', ylabel='Undamped')
ax2.set_xticks(np.arange(0,2.001, 0.5))  # <---- Tick marks only on each 0.5 second interval
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exploring common plot types through seaborn
# Shortcut so that we don't have to create axes, add tick marks, etc.

# %% [markdown]
# ## Scatterplots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
# Scatterplot
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
# Box plot and scatterplot
f, axes = plt.subplots(1, 2, sharey=True, figsize=(6, 4)) # Create 1x2 plots w/ boxplot first
sns.boxplot(x="day", y="tip", data=tips, ax=axes[0])
sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips, ax=axes[1]);

# %%
# Scatterplots - display relationship between 2 vars
# Plot the cause variable on the x-axis and the effect variable on the y-axis

# Load tips dataset and review first 5 rows
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Use the tips dataframe aka dataset and replot command to plot total bill versus the tip amount
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
# Add a 3rd variable (smoking status) - automatically adds color and legend
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
# Add a 3rd variable (size of party) - automatically adds color and legend
sns.relplot(x="total_bill", y="tip", hue="size", data=tips);

# %%
# Add a 3rd variable (size of party) - automatically adds color and legend - change icon
sns.relplot(x="total_bill", y="tip", hue="smoker", style="smoker", data=tips);

# %%
# Add a 3rd variable (size of party) - automatically adds color and legend - larger dots indicate larger parties
sns.relplot(x="total_bill", y="tip", size="size", sizes=(15, 200), data=tips);

# %% [markdown]
# ## Lineplots
# Useful for longitudinal data.

# %%
# Create 500 random numbers and graph as a lineplot
# Sorts data before plotting
df = pd.DataFrame(dict(time=np.arange(500),
                       value=np.random.randn(500).cumsum()))
g = sns.relplot(x="time", y="value", kind="line", data=df) # see line option
g.fig.autofmt_xdate()

# %% [markdown]
# ## Categorical scatterplots

# %%
# Cat var = day of the week
# Plot total bill by day of the week
tips = sns.load_dataset("tips")
sns.catplot(x="day", y="total_bill", data=tips);

# %%
# Cat var = day of the week
# Plot total bill by day of the week - but get ride of "jitter"
tips = sns.load_dataset("tips")
sns.catplot(x="day", y="total_bill", jitter=False, data=tips);

# %%
# Cat var = day of the week
# Plot total bill by day of the week - swarm plot (prevents overlapping)
# Add 3rd var (sex)
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=tips);

# %% [markdown]
# ## Boxplots

# %%
# Cat var = day of the week
# Plot total bill by day of the week - boxplot 
# (shows 1.5 interquartile range (whisker), p25 (box bottom line), p50 (center line), p75 (box top line), 1.5 interquartile range  (whisker), outliers)
sns.catplot(x="day", y="total_bill", kind="box", data=tips);

# %%
# Cat var = day of the week
# Plot total bill by day of the week - boxplot 
# (shows 1.5 interquartile range (whisker), p25 (box bottom line), p50 (center line), p75 (box top line), 1.5 interquartile range  (whisker), outliers)
# Add third variable (smoking status)
sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=tips);

# %% [markdown]
# ## Raincloud/violin plots
# Skipped.

# %% [markdown]
# ## Barplots
# Reflects cat var. Height of bar usually reflects mean.

# %%
# Load titanic dataset and review first 5 rows
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Plot probability of surviving as function of ticket class and gender
# Error bars = 95% CIs
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic);
# In general, more women survived. However, lower classes least likely to survive.

# %%
# Count the number of survivors by sex
sns.catplot(x="sex", kind="count", palette="ch:.25", data=titanic);

# %% [markdown]
# ## Point plots
# Similar to bar plots, but just a point with an error bar around it. Can connect with lines.

# %%
# Don't like this particular example - use barcharts for categorical variables. Save these for continuous variables
sns.catplot(x="class", y="survived", hue="sex",
            palette={"male": "b", "female": "r"},
            markers=["^", "o"], linestyles=["-", "--"],
            kind="point", data=titanic);

# %% [markdown]
# ##Histograms
# Histograms help reveal which values are common or typical in your data, what the shape of the overall distribution is (sometimes useful for checking the assumptions of certain statistical tests), and can help detect outliers and other anamalies in your data.

# %%
# Divide up the possible values into bins, and then count the number of observations that fall within each bin. 
# This count is referred to as the frequency of the bin, and is displayed as the height of a bar.
# Plot penguin flipper length as histogram
penguins = sns.load_dataset("penguins")
sns.displot(data=penguins, x="flipper_length_mm", kde="true", bins=10) # Add smoothed kernel-density estimate and specify bins

# %%
# Plot 2 histograms onto same plot
x = np.random.normal(0,1,size=100) # zero centered normal distribution
y = np.random.normal(3,1,size=100) # shift this one over
sns.displot([x,y])

# %% [markdown]
# ## Bivariate histograms
# Skipped

# %% [markdown]
# ## Pairwise relationship (correlation) plots

# %%
# Load flower dataset and show scatter plots of each continuous feature by species
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue="species");

# %% [markdown]
# ## Linear relationships
# Seaborn has scatterplots that will fit/display linear regression. Use lmplot.

# %%
# Compare tip by total bill
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
# Compare total bill by party size
sns.lmplot(x="size", y="total_bill", x_jitter=.05, data=tips);

# %%
# Compare tip by total bill, by smoking status
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %% [markdown]
# ## Saving figures and creating figures for publication/presentation
# Right click or use code - and then grab from left-hand menu under "files". Save as .png, .jpg, .tiff, .pdf. Can adjust dots per inch (for publication).

# %%
myfig = sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);
myfig.savefig('smoking_tips.png')

# %%
# Use paper theme (small axis and legend text)
sns.set_context("paper")
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
# Change labels and label size
sns.set_context("talk")
g=sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);
g.set_axis_labels("Total bill (dollars)", "Tip (dollars)")

# %% [markdown]
# ##Animated data and interactive plots
# Useful for audience attention. If you are interested in making a bunch of seaborn or matplotlib plots and then animating them like a flip book the [Celluloid](https://github.com/jwkvam/celluloid) package can help. The basic idea if that you make a “camera” object and snap a photo of each frame of your movie, each time replotting your figure. The library then animates it and can explore it is a movie.
#
# Skipped.
